# %% [markdown]
# **Loan Approval Prediction**

# %% [markdown]
# ***Data Manupilaction***

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\DELL\OneDrive\Desktop\ML Projects\Loan Prediction\train_ctrUa4K.csv")

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df = df.drop("Loan_ID", axis=1)

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
df.isna().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14304\3657246551.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)

# %%
df['Married'].fillna(df['Married'].mode()[0], inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14304\891759981.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Married'].fillna(df['Married'].mode()[0], inplace=True)

# %%
df['Dependents'].fillna(df['Dependents'].mode()[0], inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14304\495691802.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Dependents'].fillna(df['Dependents'].mode()[0], inplace=True)

# %%
df['Self_Employed'].fillna(df['Self_Employed'].mode()[0], inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14304\3324225749.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Self_Employed'].fillna(df['Self_Employed'].mode()[0], inplace=True)

# %%
#df['Age'].fillna(df['Age'].median(), inplace=True)
df['LoanAmount'].fillna(df['LoanAmount'].median(), inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14304\2195737922.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['LoanAmount'].fillna(df['LoanAmount'].median(), inplace=True)

# %%
df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].median(), inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14304\1787917455.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].median(), inplace=True)

# %%
df['Credit_History'].fillna(df['Credit_History'].median(), inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14304\732727286.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Credit_History'].fillna(df['Credit_History'].median(), inplace=True)

# %%
df.isna().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df['Loan_Status'] = df['Loan_Status'].map({'Y':1, 'N':0})
df['Property_Area'] = df['Property_Area'].map({'Semiurban':1, 'Rural':0, 'Urban':2})
df['Self_Employed'] = df['Self_Employed'].map({'No':0, 'Yes':1})
df['Education'] = df['Education'].map({'Graduate':1, 'Not Graduate':0})
df['Married'] = df['Married'].map({'Yes':1, 'No':0})
df['Gender'] = df['Gender'].map({'Male': 1, 'Female': 0})
df['Dependents'] = df['Dependents'].replace({'3+':3})

# %%
df.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0          0          1              0             5849
# 1       1        1          1          1              0             4583
# 2       1        1          0          1              1             3000
# 3       1        1          0          0              0             2583
# 4       1        0          0          1              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       128.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#    Property_Area  Loan_Status
# 0              2            1
# 1              0            0
# ...

# %% [markdown]
# ***Classifier***

# %%
import matplotlib as mlp
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
X = df.drop(columns=['Loan_Status'])
Y = df['Loan_Status']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, stratify=Y)

# %% [markdown]
# *Model*

# %%
from sklearn.linear_model import LogisticRegression,PassiveAggressiveClassifier,Perceptron,RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier,HistGradientBoostingClassifier, ExtraTreesClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.calibration import CalibratedClassifierCV

# %%
log_reg = LogisticRegression(max_iter=1000)  # Increased from 100 to 1000
rigde = RidgeClassifier(max_iter=1000)

models = {
    'Logistic Regression': log_reg,
    'Passive Aggressive': PassiveAggressiveClassifier(),
    'Precepton': Perceptron(),
    'Ridge': rigde,
    'Linear SVC': LinearSVC(),
    'Random Forest': RandomForestClassifier(),
    'Gradient Boosting': GradientBoostingClassifier(),
    'Histogram Gradient': HistGradientBoostingClassifier(),
    'Extra Tree': ExtraTreesClassifier(),
}

for name, model in models.items():
    y_pred = cross_val_predict(model, x_train, y_train, cv=3)
    
    score_1 = precision_score(y_train, y_pred,  average='binary')
    score_2 = recall_score(y_train, y_pred, average='binary')
    score_3 = f1_score(y_train, y_pred, average='binary')

    scores = [round(score_1,4), round(score_2,4), round(score_3,4)]
    print(f"{name}: {scores}")
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# ...

# %%
models = {
    'Extra Tree': ExtraTreesClassifier(),
    'Linear SVC': LinearSVC(),
}

for name,model in models.items():
    y_pred = cross_val_predict(model, x_test, y_test, cv=3)

    score_1 = precision_score(y_test, y_pred,  average='binary')
    score_2 = recall_score(y_test, y_pred, average='binary')
    score_3 = f1_score(y_test, y_pred, average='binary')

    scores = [round(score_1,4), round(score_2,4), round(score_3,4)]
    print(f"{name}: {scores}")
# Out:
# Extra Tree: [0.8182, 0.8471, 0.8324]
# Linear SVC: [0.8144, 0.9294, 0.8681]

# %%
base_model = LinearSVC()
calibrated_model = CalibratedClassifierCV(estimator=base_model, cv=5)

#Fit to train set
calibrated_model.fit(x_train, y_train)
# Out:
# CalibratedClassifierCV(cv=5, estimator=LinearSVC())

# %%
# Predict final output
y_pred = calibrated_model.predict(x_test)

# Predict probabilities (e.g., for threshold tuning or dashboards)
y_proba = calibrated_model.predict_proba(x_test)

# %% [markdown]
# **Final Test**

# %%
test_file = pd.read_csv(r"C:\Users\DELL\OneDrive\Desktop\ML Projects\Loan Prediction\test_lAUu6dG.csv")

# %%
test_file.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
test_file.isna().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
test_file['Gender'].fillna(test_file['Gender'].mode()[0], inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14304\2002328245.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_file['Gender'].fillna(test_file['Gender'].mode()[0], inplace=True)

# %%
test_file.isna().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
test_file['Dependents'] = test_file['Dependents'].replace({'3+':3})

# %%
test_file['Dependents'].fillna(test_file['Dependents'].mode()[0], inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14304\2778941893.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_file['Dependents'].fillna(test_file['Dependents'].mode()[0], inplace=True)

# %%
test_file['Self_Employed'] = test_file['Self_Employed'].fillna(test_file['Self_Employed'].mode()[0])

# %%
test_file['LoanAmount'].fillna(test_file['LoanAmount'].median(), inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14304\3373277914.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_file['LoanAmount'].fillna(test_file['LoanAmount'].median(), inplace=True)

# %%
test_file['Loan_Amount_Term'].fillna(test_file['Loan_Amount_Term'].median(), inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14304\2346716277.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_file['Loan_Amount_Term'].fillna(test_file['Loan_Amount_Term'].median(), inplace=True)

# %%
test_file['Credit_History'].fillna(test_file['Credit_History'].median(), inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14304\259145513.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_file['Credit_History'].fillna(test_file['Credit_History'].median(), inplace=True)

# %%
test_file['Property_Area'] = test_file['Property_Area'].map({'Semiurban':1, 'Rural':0, 'Urban':2})
test_file['Self_Employed'] = test_file['Self_Employed'].map({'No':0, 'Yes':1})
test_file['Education'] = test_file['Education'].map({'Graduate':1, 'Not Graduate':0})
test_file['Married'] = test_file['Married'].map({'Yes':1, 'No':0})
test_file['Gender'] = test_file['Gender'].map({'Male': 1, 'Female': 0})
test_file['Dependents'] = df['Dependents'].replace({'3+':3})

# %%
new_data = test_file.drop(columns=["Loan_ID"], errors="ignore")

# %%
loan_status_pred = calibrated_model.predict(new_data)

# %%
# Create a new DataFrame with predictions
final_data = pd.DataFrame()

# Attach 'Loan_ID' from the test data
final_data['Loan_ID'] = test_file['Loan_ID']

# Attach predicted 'Loan_Status'
final_data['Loan_Status'] = loan_status_pred
final_data['Loan_Status'] = final_data['Loan_Status'].map({1: 'Y', 0: 'N'})


# Save to CSV
final_data.to_csv(r"C:\Users\DELL\OneDrive\Desktop\loan_predictions_output.csv", index=False)
